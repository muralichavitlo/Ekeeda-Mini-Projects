# %% [markdown]
# # Palmer Archipelago (Antarctica) penguin data - Exploratory Data Analysis
# ## Data Set
# Link: [Palmer Archipelago (Antarctica) penguin data](https://www.kaggle.com/datasets/parulpandey/palmer-archipelago-antarctica-penguin-data)
#
# ## Apply EDA techniques like
# - Find correlation between variables
# - Plot different features
# - Detect outlier / missing values if any etc.

# %%
import pandas as pd
from pandas_profiling import ProfileReport
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
df = pd.read_csv('Palmer Archipelago (Antarctica) penguin data/penguins_lter.csv')

# %%
df.head()
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion  Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  11/11/07
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  11/11/07
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  11/16/07
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  11/16/07
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  11/16/07
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0                39.1               18.7                181.0         3750.0
# 1                39.5               17.4                186.0         3800.0
# 2                40.3               18.0                195.0         3250.0
# 3                 NaN                NaN                  NaN            NaN
# 4                36.7               19.3                193.0         3450.0
#
#       Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 0    MALE                NaN                NaN
# 1  FEMALE            8.94956          -24.69454
# 2  FEMALE            8.36821          -25.33302
# 3     NaN                NaN                NaN
# 4  FEMALE            8.76651          -25.32426
#
#                          Comments
# 0  Not enough blood for isotopes.
# 1                             NaN
# 2                             NaN
# 3              Adult not sampled.
# 4                             NaN

# %% [markdown]
# ## Pandas Profiling

# %%
profile = ProfileReport(df)
profile.to_file('report.html')

# %% [markdown]
# ## Drop Columns

# %% [markdown]
# * `Sample Number` - has 152 Distinct values (44.2%)
# * `Region` - only one region "Anvers"
# * `Stage` - only one stage "Adult, 1 Egg Stage"
# * `Individual ID` - 190 Distinct Ids (55.2%)

# %%
df = df.drop(['Sample Number', 'Region', 'Stage', 'Individual ID'], axis=1)

# %% [markdown]
# `Date Egg` columns is not in datetime format

# %%
df['Date Egg'] = pd.to_datetime(df['Date Egg'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   studyName            344 non-null    object
#  1   Species              344 non-null    object
#  2   Island               344 non-null    object
#  3   Clutch Completion    344 non-null    object
#  4   Date Egg             344 non-null    datetime64[ns]
#  5   Culmen Length (mm)   342 non-null    float64
#  6   Culmen Depth (mm)    342 non-null    float64
#  7   Flipper Length (mm)  342 non-null    float64
#  8   Body Mass (g)        342 non-null    float64
#  9   Sex                  334 non-null    object
#  10  Delta 15 N (o/oo)    330 non-null    float64
#  11  Delta 13 C (o/oo)    331 non-null    float64
#  12  Comments             26 non-null     object
# dtypes: datetime64[ns](1), float64(6), object(6)
# memory usage: 35.1+ KB

# %% [markdown]
# Number of Missing Values:

# %%
df.isna().sum()
# Out:
# studyName                0
# Species                  0
# Island                   0
# Clutch Completion        0
# Date Egg                 0
# Culmen Length (mm)       2
# Culmen Depth (mm)        2
# Flipper Length (mm)      2
# Body Mass (g)            2
# Sex                     10
# Delta 15 N (o/oo)       14
# Delta 13 C (o/oo)       13
# Comments               318
# dtype: int64

# %% [markdown]
# Numberic:
# ```
# Culmen Length (mm)       2
# Culmen Depth (mm)        2
# Flipper Length (mm)      2
# Body Mass (g)            2
# Delta 15 N (o/oo)       14
# Delta 13 C (o/oo)       13
# ```
# > for numeric columns, the 'nan' values are replaced with Median value.

# %%
for i in ['Culmen Length (mm)', 'Culmen Depth (mm)', 'Flipper Length (mm)', 
            'Body Mass (g)', 'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)']:
    df[i] = df[i].fillna(df[i].median())

# %%
df.Sex.unique()
# Out:
# array(['MALE', 'FEMALE', nan, '.'], dtype=object)

# %% [markdown]
# * There is `"."` in `Sex` column. So Drop this `"."`
# * Removing `nan`

# %%
df = df[df.Sex != '.']
df = df[~df.isna()]

# %% [markdown]
# `Comments` column has `92.4%` of missing values. So don't drop the missing values of `Comments`

# %%
df.head()
# Out:
#   studyName                              Species     Island Clutch Completion  \
# 0   PAL0708  Adelie Penguin (Pygoscelis adeliae)  Torgersen               Yes
# 1   PAL0708  Adelie Penguin (Pygoscelis adeliae)  Torgersen               Yes
# 2   PAL0708  Adelie Penguin (Pygoscelis adeliae)  Torgersen               Yes
# 3   PAL0708  Adelie Penguin (Pygoscelis adeliae)  Torgersen               Yes
# 4   PAL0708  Adelie Penguin (Pygoscelis adeliae)  Torgersen               Yes
#
#     Date Egg  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0 2007-11-11               39.10               18.7                181.0
# 1 2007-11-11               39.50               17.4                186.0
# 2 2007-11-16               40.30               18.0                195.0
# 3 2007-11-16               44.45               17.3                197.0
# 4 2007-11-16               36.70               19.3                193.0
#
#    Body Mass (g)     Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 0         3750.0    MALE           8.652405          -25.83352
# 1         3800.0  FEMALE           8.949560          -24.69454
# 2         3250.0  FEMALE           8.368210          -25.33302
# 3         4050.0     NaN           8.652405          -25.83352
# 4         3450.0  FEMALE           8.766510          -25.32426
#
#                          Comments
# 0  Not enough blood for isotopes.
# 1                             NaN
# 2                             NaN
# 3              Adult not sampled.
# 4                             NaN

# %%
sns.heatmap(df.corr(), annot=True, cmap='coolwarm');

# %% [markdown]
# Here `Flipper Length (mm)` and `Body Mass (g)` are `Highly Correlated`.

# %%
df.shape
# Out:
# (343, 13)

# %%
df1 = df.groupby(['Species']).mean()
df1
# Out:
#                                            Culmen Length (mm)  \
# Species
# Adelie Penguin (Pygoscelis adeliae)                 38.828618
# Chinstrap penguin (Pygoscelis antarctica)           48.833824
# Gentoo penguin (Pygoscelis papua)                   47.504472
#
#                                            Culmen Depth (mm)  \
# Species
# Adelie Penguin (Pygoscelis adeliae)                18.339474
# Chinstrap penguin (Pygoscelis antarctica)          18.420588
# Gentoo penguin (Pygoscelis papua)                  14.995122
#
#                                            Flipper Length (mm)  Body Mass (g)  \
# Species
# Adelie Penguin (Pygoscelis adeliae)                 190.000000    3702.960526
# Chinstrap penguin (Pygoscelis antarctica)           195.823529    3733.088235
# Gentoo penguin (Pygoscelis papua)                   217.024390    5069.308943
#
#                                            Delta 15 N (o/oo)  \
# Species
# Adelie Penguin (Pygoscelis adeliae)                 8.844729
# Chinstrap penguin (Pygoscelis antarctica)           9.345806
# Gentoo penguin (Pygoscelis papua)                   8.253618
#
#                                            Delta 13 C (o/oo)
# Species
# Adelie Penguin (Pygoscelis adeliae)               -25.806316
# Chinstrap penguin (Pygoscelis antarctica)         -24.546542
# Gentoo penguin (Pygoscelis papua)                 -26.179585

# %%
fig = px.bar(df1, barmode='group')
fig.show()

# %% [markdown]
# * Body Mass and Flipper Length of **Adelie Penguin (Pygoscelis adeliae)** and **Chinstrap penguin (Pygoscelis antarctica)** are almost Equal
# * But Body Mass and Flipper Length of **Gentoo penguin (Pygoscelis papua)** is more than these two

# %%
df2 = df.groupby('Island').mean()
df2
# Out:
#            Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# Island
# Biscoe              45.257186          15.884431           209.586826
# Dream               44.167742          18.344355           193.072581
# Torgersen           39.056731          18.407692           191.307692
#
#            Body Mass (g)  Delta 15 N (o/oo)  Delta 13 C (o/oo)
# Island
# Biscoe       4711.077844           8.403791         -26.110849
# Dream        3712.903226           9.156732         -25.091662
# Torgersen    3712.980769           8.773860         -25.767998

# %%
fig = px.bar(df2, barmode='group')
fig.show()

# %% [markdown]
# Body Mass and Flipper Length of `Biscoe` is more than `Dream` and `Torgersen` Island

# %%
df3 = df.groupby('Sex').mean()
df3
# Out:
#         Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# Sex
# FEMALE           42.096970          16.425455           197.363636
# MALE             45.854762          17.891071           204.505952
#
#         Body Mass (g)  Delta 15 N (o/oo)  Delta 13 C (o/oo)
# Sex
# FEMALE    3862.272727           8.675015         -25.683114
# MALE      4545.684524           8.799024         -25.689750

# %%
fig = px.bar(df3, barmode='group')
fig.show()

# %% [markdown]
# `Culmen Length`, `Culmen Depth (mm)`, `Flipper Length (mm)` and `Body Mass (g)` of **MALE** is higher than **FEMALE**

# %%
sns.pairplot(df, hue='Species');

# %% [markdown]
# * **Body Mass** and **Flipper Length** are `highly correlated` and **Body Mass** `increases` when **Flipper Length** is `increases`.
# * **Culmen Length** and **Flipper Length** are correlated
# * **Culmen Length** and **Body Mass** are correlated
# * **Culmen Depth** and **Delta 15 N** are correlated
# * **Delta 15 N** and **Delta 13 C** are correlated

# %%
df.corr() > 0.5
# Out:
#                      Culmen Length (mm)  Culmen Depth (mm)  \
# Culmen Length (mm)                 True              False
# Culmen Depth (mm)                 False               True
# Flipper Length (mm)                True              False
# Body Mass (g)                      True              False
# Delta 15 N (o/oo)                 False               True
# Delta 13 C (o/oo)                 False              False
#
#                      Flipper Length (mm)  Body Mass (g)  Delta 15 N (o/oo)  \
# Culmen Length (mm)                  True           True              False
# Culmen Depth (mm)                  False          False               True
# Flipper Length (mm)                 True           True              False
# Body Mass (g)                       True           True              False
# Delta 15 N (o/oo)                  False          False               True
# Delta 13 C (o/oo)                  False          False               True
#
#                      Delta 13 C (o/oo)
# Culmen Length (mm)               False
# Culmen Depth (mm)                False
# Flipper Length (mm)              False
# Body Mass (g)                    False
# Delta 15 N (o/oo)                 True
# Delta 13 C (o/oo)                 True
